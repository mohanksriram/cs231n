# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.314087
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *We are generating a random set of weights, where in there is no bias towards any of the classes.
# Logarithmic outputs would be uniformly distributed and subsequently the probabilities from the softmax function.
# In that sense, we have probability for all class outputs as x and thus x/10x -> 0.1; which leads to -log(0.1)*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -1.975745 analytic: -1.975745, relative error: 3.831230e-09
# numerical: -0.987887 analytic: -0.987887, relative error: 6.681961e-09
# numerical: 0.974653 analytic: 0.974653, relative error: 4.451949e-08
# numerical: -3.017296 analytic: -3.017296, relative error: 1.800687e-08
# numerical: 0.385274 analytic: 0.385273, relative error: 1.600924e-07
# numerical: -0.116387 analytic: -0.116388, relative error: 4.581542e-07
# numerical: -1.902230 analytic: -1.902230, relative error: 2.519982e-09
# numerical: 1.751521 analytic: 1.751521, relative error: 1.763840e-08
# numerical: -0.163124 analytic: -0.163124, relative error: 3.930992e-07
# numerical: -1.000135 analytic: -1.000135, relative error: 2.470628e-08
# numerical: -0.236793 analytic: -0.236793, relative error: 7.161416e-08
# numerical: 1.479645 analytic: 1.479645, relative error: 2.684378e-08
# numerical: -0.624705 analytic: -0.624705, relative error: 1.302584e-07
# numerical: -1.453038 analytic: -1.453038, relative error: 2.646175e-08
# numerical: 3.692703 analytic: 3.692703, relative error: 4.275185e-09
# numerical: -2.440871 analytic: -2.440871, relative error: 7.600615e-09
# numerical: -0.640005 analytic: -0.640005, relative error: 7.588308e-09
# numerical: -1.126877 analytic: -1.126877, relative error: 1.015679e-08
# numerical: -0.147587 analytic: -0.147587, relative error: 5.146562e-07
# numerical: -0.088607 analytic: -0.088607, relative error: 4.448857e-07

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.314087e+00 computed in 0.125769s
# vectorized loss: 2.314087e+00 computed in 0.003876s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 5e-5]
regularization_strengths = [2.5e4, 50e4]

lr_list = np.linspace(learning_rates[0], learning_rates[1], 5)
reg_list = np.linspace(regularization_strengths[0], regularization_strengths[1], 5)

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
for lr in lr_list:
    for reg in reg_list:
        softmax = Softmax()
        tic = time.time()
        loss_hist = softmax.train(X_train, y_train, learning_rate=lr, reg=reg,
                      num_iters=1500, verbose=True)
        toc = time.time()
        print("That took %fs" %(toc-tic))
        
        # Predict for training values
        y_train_pred = softmax.predict(X_train)
        y_train_acc = np.mean(y_train_pred == y_train)
        
        # Predict for test values
        y_val_pred = softmax.predict(X_val)
        y_val_acc = np.mean(y_val_pred == y_val)
        
        results[lr, reg] = y_val_acc
        
        if y_val_acc > best_val:
            best_val = y_val_acc
            best_softmax = softmax
            
        
        
            
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1500: loss 773.649964
# iteration 100 / 1500: loss 284.153551
# iteration 200 / 1500: loss 105.383696
# iteration 300 / 1500: loss 39.797685
# iteration 400 / 1500: loss 15.928275
# iteration 500 / 1500: loss 7.090223
# iteration 600 / 1500: loss 3.979450
# iteration 700 / 1500: loss 2.743932
# iteration 800 / 1500: loss 2.350064
# iteration 900 / 1500: loss 2.185772
# iteration 1000 / 1500: loss 2.122886
# iteration 1100 / 1500: loss 2.135787
# iteration 1200 / 1500: loss 2.095935
# iteration 1300 / 1500: loss 2.098385
# iteration 1400 / 1500: loss 2.102971
# That took 3.405729s
# iteration 0 / 1500: loss 4417.891463
# iteration 100 / 1500: loss 15.103190
# iteration 200 / 1500: loss 2.255503
# iteration 300 / 1500: loss 2.238636
# iteration 400 / 1500: loss 2.217672
# iteration 500 / 1500: loss 2.220006
# iteration 600 / 1500: loss 2.218392
# iteration 700 / 1500: loss 2.235370
# iteration 800 / 1500: loss 2.255479
# iteration 900 / 1500: loss 2.235821
# iteration 1000 / 1500: loss 2.199146
# iteration 1100 / 1500: loss 2.213989
# iteration 1200 / 1500: loss 2.191907
# iteration 1300 / 1500: loss 2.179398
# iteration 1400 / 1500: loss 2.210874
# That took 3.467772s
# iteration 0 / 1500: loss 8099.405382
# iteration 100 / 1500: loss 2.415426
# iteration 200 / 1500: loss 2.255692
# iteration 300 / 1500: loss 2.234816
# iteration 400 / 1500: loss 2.251603
# iteration 500 / 1500: loss 2.256829
# iteration 600 / 1500: loss 2.253591
# iteration 700 / 1500: loss 2.239676
# iteration 800 / 1500: loss 2.263103
# iteration 900 / 1500: loss 2.248667
# iteration 1000 / 1500: loss 2.261143
# iteration 1100 / 1500: loss 2.229000
# iteration 1200 / 1500: loss 2.242532
# iteration 1300 / 1500: loss 2.243750
# iteration 1400 / 1500: loss 2.226454
# That took 3.495840s
# iteration 0 / 1500: loss 11532.574675
# iteration 100 / 1500: loss 2.279745
# iteration 200 / 1500: loss 2.259311
# iteration 300 / 1500: loss 2.268517
# iteration 400 / 1500: loss 2.253799
# iteration 500 / 1500: loss 2.251044
# iteration 600 / 1500: loss 2.247805
# iteration 700 / 1500: loss 2.274715
# iteration 800 / 1500: loss 2.259779
# iteration 900 / 1500: loss 2.268792
# iteration 1000 / 1500: loss 2.252337
# iteration 1100 / 1500: loss 2.250292
# iteration 1200 / 1500: loss 2.251126
# iteration 1300 / 1500: loss 2.247387
# iteration 1400 / 1500: loss 2.262839
# That took 3.559160s
# iteration 0 / 1500: loss 15329.906147
# iteration 100 / 1500: loss 2.272314
# iteration 200 / 1500: loss 2.281349
# iteration 300 / 1500: loss 2.252176
# iteration 400 / 1500: loss 2.264357
# iteration 500 / 1500: loss 2.267598
# iteration 600 / 1500: loss 2.269135
# iteration 700 / 1500: loss 2.276547
# iteration 800 / 1500: loss 2.269251
# iteration 900 / 1500: loss 2.277512
# iteration 1000 / 1500: loss 2.264229
# iteration 1100 / 1500: loss 2.270897
# iteration 1200 / 1500: loss 2.261054
# iteration 1300 / 1500: loss 2.279235
# iteration 1400 / 1500: loss 2.256054
# That took 3.625789s
# iteration 0 / 1500: loss 772.414496
# iteration 100 / 1500: loss 12.594988
# iteration 200 / 1500: loss 12.201462
# iteration 300 / 1500: loss 14.381911
# iteration 400 / 1500: loss 13.579739
# iteration 500 / 1500: loss 16.074157
# iteration 600 / 1500: loss 11.183484
# iteration 700 / 1500: loss 10.647555
# iteration 800 / 1500: loss 13.687110
# iteration 900 / 1500: loss 8.479739
# iteration 1000 / 1500: loss 13.798846
# iteration 1100 / 1500: loss 10.795256
# iteration 1200 / 1500: loss 11.311137
# iteration 1300 / 1500: loss 12.328908
# iteration 1400 / 1500: loss 11.573929
# That took 3.564276s
# iteration 0 / 1500: loss 4358.636369
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# That took 3.416489s
# iteration 0 / 1500: loss 8040.157428
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# That took 3.165498s
# iteration 0 / 1500: loss 11634.260788
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# That took 3.238337s
# iteration 0 / 1500: loss 15268.749261
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# That took 3.164193s
# iteration 0 / 1500: loss 772.664623
# iteration 100 / 1500: loss 66.619176
# iteration 200 / 1500: loss 74.414714
# iteration 300 / 1500: loss 68.183833
# iteration 400 / 1500: loss 69.878149
# iteration 500 / 1500: loss 64.617354
# iteration 600 / 1500: loss 68.017098
# iteration 700 / 1500: loss 81.652640
# iteration 800 / 1500: loss 71.185268
# iteration 900 / 1500: loss 75.070669
# iteration 1000 / 1500: loss 76.504155
# iteration 1100 / 1500: loss 69.180880
# iteration 1200 / 1500: loss 74.937160
# iteration 1300 / 1500: loss 72.927788
# iteration 1400 / 1500: loss 72.068154
# That took 3.259250s
# iteration 0 / 1500: loss 4470.676896
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# That took 3.191049s
# iteration 0 / 1500: loss 8058.474555
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# That took 3.161008s
# iteration 0 / 1500: loss 11625.494729
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# That took 3.173745s
# iteration 0 / 1500: loss 15459.946147
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# That took 3.199829s
# iteration 0 / 1500: loss 769.326164
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# That took 3.166768s
# iteration 0 / 1500: loss 4416.785830
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# That took 3.602011s
# iteration 0 / 1500: loss 8097.079951
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# That took 3.188149s
# iteration 0 / 1500: loss 11698.455203
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# That took 3.177210s
# iteration 0 / 1500: loss 15442.151631
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# That took 3.161145s
# iteration 0 / 1500: loss 776.183469
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# That took 3.172495s
# iteration 0 / 1500: loss 4421.940293
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# That took 3.170409s
# iteration 0 / 1500: loss 8091.249246
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# That took 3.187703s
# iteration 0 / 1500: loss 11566.604092
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# That took 3.485911s
# iteration 0 / 1500: loss 15326.601864
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# That took 3.372795s
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-e550fa789325> in <module>()
#      51 # Print out results.
#      52 for lr, reg in sorted(results):
# ---> 53     train_accuracy, val_accuracy = results[(lr, reg)]
#      54     print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
#      55                 lr, reg, train_accuracy, val_accuracy))
#
# TypeError: 'numpy.float64' object is not iterable

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.333000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
